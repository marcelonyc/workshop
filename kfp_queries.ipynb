# %%
import kfp

# %%
Client = kfp.Client('http://ml-pipeline:8888')

# %%
Client.list_experiments()
# Out:
# {'experiments': [{'created_at': datetime.datetime(2020, 1, 12, 13, 20, 18, tzinfo=tzlocal()),
#                   'description': 'All runs created without specifying an '
#                                  'experiment will be grouped here.',
#                   'id': '2671f653-3b7b-4206-a82c-4909880ad03b',
#                   'name': 'Default'},
#                  {'created_at': datetime.datetime(2020, 1, 16, 17, 31, 46, tzinfo=tzlocal()),
#                   'description': None,
#                   'id': '5eb2bd06-1b19-498b-8b1c-405d0c7eee88',
#                   'name': 'example'},
#                  {'created_at': datetime.datetime(2020, 2, 13, 16, 1, 53, tzinfo=tzlocal()),
#                   'description': None,
#                   'id': 'b94ee0c5-0414-4f3c-9e5f-36266e672fc5',
#                   'name': 'dask'}],
#  'next_page_token': None,
#  'total_size': 3}

# %%
Client.list_runs()
# Out:
# {'next_page_token': None,
#  'runs': [{'created_at': datetime.datetime(2020, 1, 16, 17, 31, 46, tzinfo=tzlocal()),
#            'description': None,
#            'error': None,
#            'finished_at': datetime.datetime(2020, 1, 16, 17, 32, 36, tzinfo=tzlocal()),
#            'id': 'de395735-acbe-4233-a46e-de3ac6026a25',
#            'metrics': None,
#            'name': 'example 1',
#            'pipeline_spec': {'parameters': [{'name': 'p1',
#                                              'value': '[1, 2, 3, 4, 5, 6]'},
#                                             {'name': 'p2',
#                                              'value': '[9, 8, 6, 5, 4, 3]'}],
#                              'pipeline_id': None,
#                              'pipeline_manifest': None,
#                              'pipeline_name': None,
#                              'workflow_manifest': '{"apiVersion": '
#                                                   '"argoproj.io/v1alpha1", '
# ...
